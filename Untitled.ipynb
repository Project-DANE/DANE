# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cws_residents.csv')

# %%
df = df.drop(columns = ['HMY', 'HMYPerson', 'Rent', 'SRENT', 'hTenant', 'hTent', 'HMY1'])

# %%
charge_codes = [96, 105, 106, 115, 127, 131, 137, 138,142, 148, 154,
                155, 156, 163, 166, 169, 183, 189, 192, 229, 231, 233,
                245, 246, 247, 248, 249,250, 251, 253, 268, 298]

# %%
df
# Out:
#         HPerson  STOTALAMOUNT  SAmountPaid  BOPEN  HRetentionacct  \
# 0          3946          5.00         5.00      0             191
# 1          3946         13.67        13.67      0             112
# 2          3946       1311.00      1311.00      0              74
# 3          3946         13.00        13.00      0             129
# 4          3946         42.92        42.92      0             111
# ...         ...           ...          ...    ...             ...
# 739437    74273          4.17         4.17      0             191
# 739438    74273         65.00        65.00      0             134
# 739439    74273          5.00         5.00      0             186
# 739440    74273       2074.17      2074.17      0              74
# 739441    74273         65.00        65.00      0             134
#
#                                                    SNOTES  HProperty  \
# 0                                   Amenity fee (08/2022)        136
# 1                                            Water Charge        136
# 2                                          Rent (12/2022)        136
# 3                         Utility-trash charges (10/2021)        136
# 4                                            Sewer Charge        136
# ...                                                   ...        ...
# 739437                            Amenity Fee for 25 days        112
# 739438  Non-Refundable Application Fee (Tremendous Joh...        112
# 739439                     Convenience Fee (Todre Butler)        112
# 739440                                   Rent for 25 days        112
# 739441      Non-Refundable Application Fee (Todre Butler)        112
#
#                                SNAME   sStatus  cRent  iTerm  dIncome  \
# 0                        Amenity fee  Approved   1999      2    52500
# 1              Utility-water charges  Approved   1999      2    52500
# 2                               Rent  Approved   1999      2    52500
# 3              Utility-trash charges  Approved   1999      2    52500
# 4              Utility-sewer charges  Approved   1999      2    52500
# ...                              ...       ...    ...    ...      ...
# 739437                   Amenity fee   Current   2489     15     4800
# 739438               Application fee   Current   2489     15     4800
# 739439  OSP resident convenience fee   Current   2489     15     4800
# 739440                          Rent   Current   2489     15     4800
# 739441               Application fee   Current   2489     15     4800
#
#         GuarantorRequired  TotalIncome                        Recommendation  \
# 0                   False       666000                                Accept
# 1                   False       666000                                Accept
# 2                   False       666000                                Accept
# 3                   False       666000                                Accept
# 4                   False       666000                                Accept
# ...                   ...          ...                                   ...
# 739437              False       153816  Accept with Conditions (Max Deposit)
# 739438              False       153816  Accept with Conditions (Max Deposit)
# 739439              False       153816  Accept with Conditions (Max Deposit)
# 739440              False       153816  Accept with Conditions (Max Deposit)
# 739441              False       153816  Accept with Conditions (Max Deposit)
#
#         AverageApplicantAge  AvgRiskScore  \
# 0                        33           745
# 1                        33           745
# 2                        33           745
# 3                        33           745
# 4                        33           745
# ...                     ...           ...
# 739437                   37           595
# 739438                   37           595
# 739439                   37           595
# 739440                   37           595
# 739441                   37           595
#
#               ReasonThatDroveDecisionDescription
# 0       Insufficient period of Residence History
# 1       Insufficient period of Residence History
# 2       Insufficient period of Residence History
# 3       Insufficient period of Residence History
# 4       Insufficient period of Residence History
# ...                                          ...
# 739437                 High level of Charge-offs
# 739438                 High level of Charge-offs
# 739439                 High level of Charge-offs
# 739440                 High level of Charge-offs
# 739441                 High level of Charge-offs
#
# [739442 rows x 18 columns]

# %%
df = df.rename(columns = {'HPerson': 'id',
                   'STOTALAMOUNT': 'total_charges',
                   'SAmountPaid': 'amount_paid',
                   'BOPEN': 'open',
                   'SNOTES': 'description',
                   'HRetentionacct': 'charge_code',
                   'HProperty': 'prop_id',
                   'SNAME':'charge_name',
                   'cRent': 'rent',
                   'iTerm': 'term',
                   'dIncome': 'monthly_inc',
                   'TotalIncome': 'total_inc',
                   'AverageApplicantAge': 'age',
                   'AvgRiskScore':'risk_score',
                   'ReasonThatDroveDecisionDescription': 'reason'})

# %%
df
# Out:
#            id  total_charges  amount_paid  open  charge_code  \
# 0        3946           5.00         5.00     0          191
# 1        3946          13.67        13.67     0          112
# 2        3946        1311.00      1311.00     0           74
# 3        3946          13.00        13.00     0          129
# 4        3946          42.92        42.92     0          111
# ...       ...            ...          ...   ...          ...
# 739437  74273           4.17         4.17     0          191
# 739438  74273          65.00        65.00     0          134
# 739439  74273           5.00         5.00     0          186
# 739440  74273        2074.17      2074.17     0           74
# 739441  74273          65.00        65.00     0          134
#
#                                               description  prop_id  \
# 0                                   Amenity fee (08/2022)      136
# 1                                            Water Charge      136
# 2                                          Rent (12/2022)      136
# 3                         Utility-trash charges (10/2021)      136
# 4                                            Sewer Charge      136
# ...                                                   ...      ...
# 739437                            Amenity Fee for 25 days      112
# 739438  Non-Refundable Application Fee (Tremendous Joh...      112
# 739439                     Convenience Fee (Todre Butler)      112
# 739440                                   Rent for 25 days      112
# 739441      Non-Refundable Application Fee (Todre Butler)      112
#
#                          charge_name   sStatus  rent  term  monthly_inc  \
# 0                        Amenity fee  Approved  1999     2        52500
# 1              Utility-water charges  Approved  1999     2        52500
# 2                               Rent  Approved  1999     2        52500
# 3              Utility-trash charges  Approved  1999     2        52500
# 4              Utility-sewer charges  Approved  1999     2        52500
# ...                              ...       ...   ...   ...          ...
# 739437                   Amenity fee   Current  2489    15         4800
# 739438               Application fee   Current  2489    15         4800
# 739439  OSP resident convenience fee   Current  2489    15         4800
# 739440                          Rent   Current  2489    15         4800
# 739441               Application fee   Current  2489    15         4800
#
#         GuarantorRequired  total_inc                        Recommendation  \
# 0                   False     666000                                Accept
# 1                   False     666000                                Accept
# 2                   False     666000                                Accept
# 3                   False     666000                                Accept
# 4                   False     666000                                Accept
# ...                   ...        ...                                   ...
# 739437              False     153816  Accept with Conditions (Max Deposit)
# 739438              False     153816  Accept with Conditions (Max Deposit)
# 739439              False     153816  Accept with Conditions (Max Deposit)
# 739440              False     153816  Accept with Conditions (Max Deposit)
# 739441              False     153816  Accept with Conditions (Max Deposit)
#
#         age  risk_score                                    reason
# 0        33         745  Insufficient period of Residence History
# 1        33         745  Insufficient period of Residence History
# 2        33         745  Insufficient period of Residence History
# 3        33         745  Insufficient period of Residence History
# 4        33         745  Insufficient period of Residence History
# ...     ...         ...                                       ...
# 739437   37         595                 High level of Charge-offs
# 739438   37         595                 High level of Charge-offs
# 739439   37         595                 High level of Charge-offs
# 739440   37         595                 High level of Charge-offs
# 739441   37         595                 High level of Charge-offs
#
# [739442 rows x 18 columns]

# %%
df = df[df.sStatus == 'Current']

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#            id  total_charges  amount_paid  open  charge_code  \
# 0        3946        1311.00      1311.00     0           74
# 1        3946        1311.00      1311.00     0           74
# 2        3946           1.83         1.83     0          191
# 3        3946          27.00        27.00     0          128
# 4        3946          21.93        21.93     0          112
# ...       ...            ...          ...   ...          ...
# 231215  74273           4.17         4.17     0          191
# 231216  74273          65.00        65.00     0          134
# 231217  74273           5.00         5.00     0          186
# 231218  74273        2074.17      2074.17     0           74
# 231219  74273          65.00        65.00     0          134
#
#                                               description  prop_id  \
# 0                                          Rent (06/2022)      136
# 1                                          Rent (08/2022)      136
# 2                           Amenity fee (11/2021) 11 days      136
# 3                             Trash service fee (07/2022)      136
# 4       Water Charge 01/03/2023 to 02/14/2023 :Final U...      136
# ...                                                   ...      ...
# 231215                            Amenity Fee for 25 days      112
# 231216  Non-Refundable Application Fee (Tremendous Joh...      112
# 231217                     Convenience Fee (Todre Butler)      112
# 231218                                   Rent for 25 days      112
# 231219      Non-Refundable Application Fee (Todre Butler)      112
#
#                          charge_name  sStatus  rent  term  monthly_inc  \
# 0                               Rent  Current  1311    15        52500
# 1                               Rent  Current  1311    15        52500
# 2                        Amenity fee  Current  1311    15        52500
# 3                  Trash service fee  Current  1311    15        52500
# 4              Utility-water charges  Current  1311    15        52500
# ...                              ...      ...   ...   ...          ...
# 231215                   Amenity fee  Current  2489    15         4800
# 231216               Application fee  Current  2489    15         4800
# 231217  OSP resident convenience fee  Current  2489    15         4800
# 231218                          Rent  Current  2489    15         4800
# 231219               Application fee  Current  2489    15         4800
#
#         GuarantorRequired  total_inc                        Recommendation  \
# 0                   False     666000                                Accept
# 1                   False     666000                                Accept
# 2                   False     666000                                Accept
# 3                   False     666000                                Accept
# 4                   False     666000                                Accept
# ...                   ...        ...                                   ...
# 231215              False     153816  Accept with Conditions (Max Deposit)
# 231216              False     153816  Accept with Conditions (Max Deposit)
# 231217              False     153816  Accept with Conditions (Max Deposit)
# 231218              False     153816  Accept with Conditions (Max Deposit)
# 231219              False     153816  Accept with Conditions (Max Deposit)
#
#         age  risk_score                                    reason
# 0        33         745  Insufficient period of Residence History
# 1        33         745  Insufficient period of Residence History
# 2        33         745  Insufficient period of Residence History
# 3        33         745  Insufficient period of Residence History
# 4        33         745  Insufficient period of Residence History
# ...     ...         ...                                       ...
# 231215   37         595                 High level of Charge-offs
# 231216   37         595                 High level of Charge-offs
# 231217   37         595                 High level of Charge-offs
# 231218   37         595                 High level of Charge-offs
# 231219   37         595                 High level of Charge-offs
#
# [231220 rows x 18 columns]
